# %% [markdown]
# ## Import bibliotek

# %%
import requests

# %% [markdown]
# ## Pobrane z serwisu [Ceneo.pl] opinii o wybranym produkcie

# %% [markdown]
# Potecjalne produkty:
# - 124893467
# - 106545192
# - 32918774
# - 83177636
# - 91869341

# %% [markdown]
# ### Wysłania żądania dostępu do zasobu (strony WWW)
